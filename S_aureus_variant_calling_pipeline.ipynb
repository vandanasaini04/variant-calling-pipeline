# %%
# !wget https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR103/021/SRR10346521/SRR10346521_1.fastq.gz
# !wget https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR103/021/SRR10346521/SRR10346521_2.fastq.gz
# Out:
# --2026-08-12 08:28:02--  https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR103/021/SRR10346521/SRR10346521_1.fastq.gz
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 575946 (562K) [application/x-gzip]
# Saving to: ‘SRR10346521_1.fastq.gz’
#
# SRR10346521_1.fastq 100%[===================>] 562.45K   797KB/s    in 0.7s
#
# 2026-08-12 08:28:04 (797 KB/s) - ‘SRR10346521_1.fastq.gz’ saved [575946/575946]
#
# --2026-08-12 08:28:04--  https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR103/021/SRR10346521/SRR10346521_2.fastq.gz
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 639829 (625K) [application/x-gzip]
# Saving to: ‘SRR10346521_2.fastq.gz’
#
# ...

# %%
# !apt-get install -y fastqc
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   at-spi2-core default-jre default-jre-headless fonts-dejavu-core
#   fonts-dejavu-extra gsettings-desktop-schemas libapache-pom-java
#   libargs4j-java libatk-bridge2.0-0 libatk-wrapper-java
#   libatk-wrapper-java-jni libatk1.0-0 libatk1.0-data libatspi2.0-0
#   libcommons-compress-java libcommons-io-java libcommons-jexl2-java
#   libcommons-lang3-java libcommons-logging-java libcommons-math3-java
#   libcommons-parent-java libfindbin-libs-perl libhtsjdk-java libjbzip2-java
#   libjson-simple-java libngs-java libngs-sdk-dev libngs-sdk2 libsis-base-java
#   libsis-base-jni libsis-jhdf5-java libsis-jhdf5-jni libsnappy-java
#   libsnappy-jni libxcomposite1 libxtst6 libxxf86dga1 openjdk-11-jre
#   openjdk-11-jre-headless session-migration x11-utils
# Suggested packages:
# ...

# %%
# !fastqc SRR10346521_1.fastq.gz SRR10346521_2.fastq.gz
# Out:
# [0.017s][warning][os,container] Cgroup memory controller path at '/sys/fs/cgroup' seems to have moved to '/../../jupyter-children', detected limits won't be accurate
# [0.017s][warning][os,container] Cgroup cpu controller path at '/sys/fs/cgroup' seems to have moved to '/../../jupyter-children', detected limits won't be accurate
# Started analysis of SRR10346521_1.fastq.gz
# Approx 15% complete for SRR10346521_1.fastq.gz
# Approx 35% complete for SRR10346521_1.fastq.gz
# Approx 55% complete for SRR10346521_1.fastq.gz
# Approx 70% complete for SRR10346521_1.fastq.gz
# Approx 90% complete for SRR10346521_1.fastq.gz
# Analysis complete for SRR10346521_1.fastq.gz
# Started analysis of SRR10346521_2.fastq.gz
# Approx 15% complete for SRR10346521_2.fastq.gz
# Approx 35% complete for SRR10346521_2.fastq.gz
# Approx 55% complete for SRR10346521_2.fastq.gz
# Approx 70% complete for SRR10346521_2.fastq.gz
# Approx 90% complete for SRR10346521_2.fastq.gz
# ...

# %%
import os
os.listdir('.')
# Out:
# ['.config',
#  'SRR10346521_2_fastqc.zip',
#  'SRR10346521_2_fastqc.html',
#  'SRR10346521_1_fastqc.zip',
#  'SRR10346521_1_fastqc.html',
#  'SRR10346521_2.fastq.gz',
#  'SRR10346521_1.fastq.gz',
#  'sample_data']

# %%
from google.colab import files
files.download('SRR10346521_1_fastqc.html')

# %%
# !apt-get install -y trimmomatic
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   trimmomatic
# 0 upgraded, 1 newly installed, 0 to remove and 24 not upgraded.
# Need to get 758 kB of archives.
# After this operation, 804 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 trimmomatic all 0.39+dfsg-2 [758 kB]
# Fetched 758 kB in 1s (1,062 kB/s)
# Selecting previously unselected package trimmomatic.
# (Reading database ... 119361 files and directories currently installed.)
# Preparing to unpack .../trimmomatic_0.39+dfsg-2_all.deb ...
# Unpacking trimmomatic (0.39+dfsg-2) ...
# Setting up trimmomatic (0.39+dfsg-2) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !trimmomatic PE SRR10346521_1.fastq.gz SRR10346521_2.fastq.gz \
    R1_paired.fastq.gz R1_unpaired.fastq.gz \
    R2_paired.fastq.gz R2_unpaired.fastq.gz \
    LEADING:3 TRAILING:3 SLIDINGWINDOW:4:15 MINLEN:36
# Out:
# /bin/bash: line 1: trimmomatic: command not found

# %%
# !TrimmomaticPE SRR10346521_1.fastq.gz SRR10346521_2.fastq.gz \
    R1_paired.fastq.gz R1_unpaired.fastq.gz \
    R2_paired.fastq.gz R2_unpaired.fastq.gz \
    LEADING:3 TRAILING:3 SLIDINGWINDOW:4:15 MINLEN:36
# Out:
# [0.000s][warning][os,container] Cgroup memory controller path at '/sys/fs/cgroup' seems to have moved to '/../../jupyter-children', detected limits won't be accurate
# [0.001s][warning][os,container] Cgroup cpu controller path at '/sys/fs/cgroup' seems to have moved to '/../../jupyter-children', detected limits won't be accurate
# TrimmomaticPE: Started with arguments:
#  SRR10346521_1.fastq.gz SRR10346521_2.fastq.gz R1_paired.fastq.gz R1_unpaired.fastq.gz R2_paired.fastq.gz R2_unpaired.fastq.gz LEADING:3 TRAILING:3 SLIDINGWINDOW:4:15 MINLEN:36
# Multiple cores found: Using 2 threads
# Quality encoding detected as phred33
# Input Read Pairs: 5450 Both Surviving: 5420 (99.45%) Forward Only Surviving: 17 (0.31%) Reverse Only Surviving: 12 (0.22%) Dropped: 1 (0.02%)
# TrimmomaticPE: Completed successfully

# %%
# !apt-get install -y bwa samtools
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libhts3 libhtscodecs2
# Suggested packages:
#   cwltool
# The following NEW packages will be installed:
#   bwa libhts3 libhtscodecs2 samtools
# 0 upgraded, 4 newly installed, 0 to remove and 24 not upgraded.
# Need to get 1,158 kB of archives.
# After this operation, 2,736 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 bwa amd64 0.7.17-6 [195 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhtscodecs2 amd64 1.1.1-3 [53.2 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhts3 amd64 1.13+ds-2build1 [390 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 samtools amd64 1.13-4 [520 kB]
# Fetched 1,158 kB in 1s (1,338 kB/s)
# Selecting previously unselected package bwa.
# ...

# %%
# !wget "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/013/425/GCF_000013425.1_ASM1342v1/GCF_000013425.1_ASM1342v1_genomic.fna.gz" -O usa300_reference.fna.gz
# !gunzip usa300_reference.fna.gz
# Out:
# --2026-08-12 08:28:51--  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/013/425/GCF_000013425.1_ASM1342v1/GCF_000013425.1_ASM1342v1_genomic.fna.gz
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.13, 2607:f220:41e:250::12, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 820675 (801K) [application/x-gzip]
# Saving to: ‘usa300_reference.fna.gz’
#
# usa300_reference.fn 100%[===================>] 801.44K  3.42MB/s    in 0.2s
#
# 2026-08-12 08:28:52 (3.42 MB/s) - ‘usa300_reference.fna.gz’ saved [820675/820675]

# %%
# !bwa index usa300_reference.fna
# Out:
# [bwa_index] Pack FASTA... 0.02 sec
# [bwa_index] Construct BWT for the packed sequence...
# [bwa_index] 0.68 seconds elapse.
# [bwa_index] Update BWT... 0.01 sec
# [bwa_index] Pack forward-only FASTA... 0.01 sec
# [bwa_index] Construct SA from BWT and Occ... 0.35 sec
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa index usa300_reference.fna
# [main] Real time: 1.125 sec; CPU: 1.081 sec

# %%
# !bwa mem usa300_reference.fna R1_paired.fastq.gz R2_paired.fastq.gz > aligned.sam
# Out:
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 10840 sequences (2293724 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 0, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] skip orientation FR as there are not enough pairs
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 10840 reads in 9.638 CPU sec, 9.759 real sec
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem usa300_reference.fna R1_paired.fastq.gz R2_paired.fastq.gz
# [main] Real time: 9.821 sec; CPU: 9.684 sec

# %%
# !samtools view -bS aligned.sam | samtools sort -o aligned_sorted.bam
# !samtools index aligned_sorted.bam

# %%
# !samtools flagstat aligned_sorted.bam
# Out:
# 10850 + 0 in total (QC-passed reads + QC-failed reads)
# 10840 + 0 primary
# 0 + 0 secondary
# 10 + 0 supplementary
# 0 + 0 duplicates
# 0 + 0 primary duplicates
# 8106 + 0 mapped (74.71% : N/A)
# 8096 + 0 primary mapped (74.69% : N/A)
# 10840 + 0 paired in sequencing
# 5420 + 0 read1
# 5420 + 0 read2
# 0 + 0 properly paired (0.00% : N/A)
# 7806 + 0 with itself and mate mapped
# 290 + 0 singletons (2.68% : N/A)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)

# %%
# !apt-get install -y freebayes
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libdisorder0 libfastahack0 libfml0 libseqlib2 libsmithwaterman0 libssw0
#   libtabixpp0 libvcflib1 parallel sysstat
# Suggested packages:
#   ash csh fish ksh tcsh zsh isag
# The following NEW packages will be installed:
#   freebayes libdisorder0 libfastahack0 libfml0 libseqlib2 libsmithwaterman0
#   libssw0 libtabixpp0 libvcflib1 parallel sysstat
# 0 upgraded, 11 newly installed, 0 to remove and 24 not upgraded.
# Need to get 4,437 kB of archives.
# After this operation, 8,967 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfml0 amd64 0.1+git20190320.b499514-1 [70.6 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libssw0 amd64 1.1-13 [19.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libseqlib2 amd64 1.2.0+dfsg-8build1 [175 kB]
# ...

# %%
# !freebayes -f usa300_reference.fna aligned_sorted.bam > variants.vcf
# Out:
# index file usa300_reference.fna.fai not found, generating...

# %%
# !wc -l variants.vcf
# Out:
# 61 variants.vcf

# %%
# !grep -v "^#" variants.vcf | head -20

# %%
# !cat variants.vcf | tail -20
# Out:
# ##INFO=<ID=NUMALT,Number=1,Type=Integer,Description="Number of unique non-reference alleles in called genotypes at this position.">
# ##INFO=<ID=MEANALT,Number=A,Type=Float,Description="Mean number of unique non-reference allele observations per sample with the corresponding alternate alleles.">
# ##INFO=<ID=LEN,Number=A,Type=Integer,Description="allele length">
# ##INFO=<ID=MQM,Number=A,Type=Float,Description="Mean mapping quality of observed alternate alleles">
# ##INFO=<ID=MQMR,Number=1,Type=Float,Description="Mean mapping quality of observed reference alleles">
# ##INFO=<ID=PAIRED,Number=A,Type=Float,Description="Proportion of observed alternate alleles which are supported by properly paired read fragments">
# ##INFO=<ID=PAIREDR,Number=1,Type=Float,Description="Proportion of observed reference alleles which are supported by properly paired read fragments">
# ##INFO=<ID=MIN_DP,Number=1,Type=Integer,Description="Minimum depth in gVCF output block.">
# ...

# %%
# !freebayes -f usa300_reference.fna aligned_sorted.bam \
    --min-coverage 1 \
    --min-alternate-count 1 \
    --min-alternate-fraction 0.01 > variants2.vcf
# !grep -v "^#" variants2.vcf | wc -l
# Out:
# 0

# %%
# !wget https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR114/052/SRR11453152/SRR11453152_1.fastq.gz
# !wget https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR114/052/SRR11453152/SRR11453152_2.fastq.gz
# Out:
# --2026-08-12 08:29:16--  https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR114/052/SRR11453152/SRR11453152_1.fastq.gz
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2026-08-12 08:29:17 ERROR 404: Not Found.
#
# --2026-08-12 08:29:17--  https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR114/052/SRR11453152/SRR11453152_2.fastq.gz
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2026-08-12 08:29:18 ERROR 404: Not Found.

# %%
# !freebayes -f usa300_reference.fna aligned_sorted.bam \
    --min-coverage 1 \
    --min-alternate-count 1 \
    --min-alternate-fraction 0.001 \
    --pooled-continuous > variants3.vcf
# !grep -v "^#" variants3.vcf | wc -l
# Out:
# 0

# %%
# !wget -O highcov_1.fastq.gz "https://ftp.sra.ebi.ac.uk/vol1/fastq/ERR752/ERR752463/ERR752463_1.fastq.gz"
# !wget -O highcov_2.fastq.gz "https://ftp.sra.ebi.ac.uk/vol1/fastq/ERR752/ERR752463/ERR752463_2.fastq.gz"
# Out:
# --2026-08-12 08:29:18--  https://ftp.sra.ebi.ac.uk/vol1/fastq/ERR752/ERR752463/ERR752463_1.fastq.gz
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2026-08-12 08:29:19 ERROR 404: Not Found.
#
# --2026-08-12 08:29:19--  https://ftp.sra.ebi.ac.uk/vol1/fastq/ERR752/ERR752463/ERR752463_2.fastq.gz
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2026-08-12 08:29:20 ERROR 404: Not Found.

# %%
# !pip install -q sra-tools
# !fasterq-dump SRR8599083 --split-files
# !ls *.fastq
# Out:
# ERROR: Could not find a version that satisfies the requirement sra-tools (from versions: none)
# ERROR: No matching distribution found for sra-tools
# /bin/bash: line 1: fasterq-dump: command not found
# ls: cannot access '*.fastq': No such file or directory

# %%
# !wget -O s1.fastq.gz "https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR859/003/SRR8599083/SRR8599083_1.fastq.gz"
# !wget -O s2.fastq.gz "https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR859/003/SRR8599083/SRR8599083_2.fastq.gz"
# Out:
# --2026-08-12 08:29:25--  https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR859/003/SRR8599083/SRR8599083_1.fastq.gz
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 139550633 (133M) [application/x-gzip]
# Saving to: ‘s1.fastq.gz’
#
# s1.fastq.gz         100%[===================>] 133.08M  1019KB/s    in 2m 8s
#
# 2026-08-12 08:31:34 (1.04 MB/s) - ‘s1.fastq.gz’ saved [139550633/139550633]
#
# --2026-08-12 08:31:34--  https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR859/003/SRR8599083/SRR8599083_2.fastq.gz
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 144479333 (138M) [application/x-gzip]
# Saving to: ‘s2.fastq.gz’
#
# ...

# %%
# !TrimmomaticPE s1.fastq.gz s2.fastq.gz \
    s1_paired.fastq.gz s1_unpaired.fastq.gz \
    s2_paired.fastq.gz s2_unpaired.fastq.gz \
    LEADING:3 TRAILING:3 SLIDINGWINDOW:4:15 MINLEN:36
# Out:
# [0.001s][warning][os,container] Cgroup memory controller path at '/sys/fs/cgroup' seems to have moved to '/../../jupyter-children', detected limits won't be accurate
# [0.001s][warning][os,container] Cgroup cpu controller path at '/sys/fs/cgroup' seems to have moved to '/../../jupyter-children', detected limits won't be accurate
# TrimmomaticPE: Started with arguments:
#  s1.fastq.gz s2.fastq.gz s1_paired.fastq.gz s1_unpaired.fastq.gz s2_paired.fastq.gz s2_unpaired.fastq.gz LEADING:3 TRAILING:3 SLIDINGWINDOW:4:15 MINLEN:36
# Multiple cores found: Using 2 threads
# Quality encoding detected as phred33
# Input Read Pairs: 2350084 Both Surviving: 2246809 (95.61%) Forward Only Surviving: 89036 (3.79%) Reverse Only Surviving: 8293 (0.35%) Dropped: 5946 (0.25%)
# TrimmomaticPE: Completed successfully

# %%
# !bwa mem usa300_reference.fna s1_paired.fastq.gz s2_paired.fastq.gz > aligned2.sam
# !samtools view -bS aligned2.sam | samtools sort -o aligned2_sorted.bam
# !samtools index aligned2_sorted.bam
# !samtools flagstat aligned2_sorted.bam
# Out:
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 100568 sequences (10000131 bp)...
# [M::process] read 100546 sequences (10000185 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 0, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] skip orientation FR as there are not enough pairs
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 100568 reads in 5.630 CPU sec, 5.465 real sec
# [M::process] read 100598 sequences (10000045 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 0, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] skip orientation FR as there are not enough pairs
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# ...

# %%
# !wget -O aureus_1.fastq.gz "https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR234/004/SRR2342134/SRR2342134_1.fastq.gz"
# !wget -O aureus_2.fastq.gz "https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR234/004/SRR2342134/SRR2342134_2.fastq.gz"
# Out:
# --2026-08-12 08:41:07--  https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR234/004/SRR2342134/SRR2342134_1.fastq.gz
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2026-08-12 08:41:08 ERROR 404: Not Found.
#
# --2026-08-12 08:41:08--  https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR234/004/SRR2342134/SRR2342134_2.fastq.gz
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2026-08-12 08:41:09 ERROR 404: Not Found.

# %%
# !pip install -q sra-tools
# !prefetch SRR8359173
# !fasterq-dump SRR8359173 --split-files
# Out:
# ERROR: Could not find a version that satisfies the requirement sra-tools (from versions: none)
# ERROR: No matching distribution found for sra-tools
# /bin/bash: line 1: prefetch: command not found
# /bin/bash: line 1: fasterq-dump: command not found

# %%
# !curl "https://www.ebi.ac.uk/ena/portal/api/filereport?accession=SRR8359173&result=read_run&fields=fastq_ftp&format=tsv"
# Out:
# run_accession	fastq_ftp
# SRR8359173	ftp.sra.ebi.ac.uk/vol1/fastq/SRR835/003/SRR8359173/SRR8359173_1.fastq.gz;ftp.sra.ebi.ac.uk/vol1/fastq/SRR835/003/SRR8359173/SRR8359173_2.fastq.gz

# %%
# !wget -O final_1.fastq.gz "https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR835/003/SRR8359173/SRR8359173_1.fastq.gz"
# !wget -O final_2.fastq.gz "https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR835/003/SRR8359173/SRR8359173_2.fastq.gz"
# Out:
# --2026-08-12 08:52:32--  https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR835/003/SRR8359173/SRR8359173_1.fastq.gz
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 328852807 (314M) [application/x-gzip]
# Saving to: ‘final_1.fastq.gz’
#
# final_1.fastq.gz    100%[===================>] 313.62M  1.13MB/s    in 4m 16s
#
# 2026-08-12 08:56:49 (1.22 MB/s) - ‘final_1.fastq.gz’ saved [328852807/328852807]
#
# --2026-08-12 08:56:50--  https://ftp.sra.ebi.ac.uk/vol1/fastq/SRR835/003/SRR8359173/SRR8359173_2.fastq.gz
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322231045 (307M) [application/x-gzip]
# Saving to: ‘final_2.fastq.gz’
#
# ...

# %%
# !TrimmomaticPE final_1.fastq.gz final_2.fastq.gz \
    final_1_paired.fastq.gz final_1_unpaired.fastq.gz \
    final_2_paired.fastq.gz final_2_unpaired.fastq.gz \
    LEADING:3 TRAILING:3 SLIDINGWINDOW:4:15 MINLEN:36
# Out:
# [0.001s][warning][os,container] Cgroup memory controller path at '/sys/fs/cgroup' seems to have moved to '/../../jupyter-children', detected limits won't be accurate
# [0.001s][warning][os,container] Cgroup cpu controller path at '/sys/fs/cgroup' seems to have moved to '/../../jupyter-children', detected limits won't be accurate
# TrimmomaticPE: Started with arguments:
#  final_1.fastq.gz final_2.fastq.gz final_1_paired.fastq.gz final_1_unpaired.fastq.gz final_2_paired.fastq.gz final_2_unpaired.fastq.gz LEADING:3 TRAILING:3 SLIDINGWINDOW:4:15 MINLEN:36
# Multiple cores found: Using 2 threads
# Quality encoding detected as phred33
# Input Read Pairs: 5019157 Both Surviving: 4834525 (96.32%) Forward Only Surviving: 143389 (2.86%) Reverse Only Surviving: 27236 (0.54%) Dropped: 14007 (0.28%)
# TrimmomaticPE: Completed successfully

# %%
# !bwa mem usa300_reference.fna final_1_paired.fastq.gz final_2_paired.fastq.gz > final_aligned.sam
# !samtools view -bS final_aligned.sam | samtools sort -o final_sorted.bam
# !samtools index final_sorted.bam
# !samtools flagstat final_sorted.bam
# Out:
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 80856 sequences (10000030 bp)...
# [M::process] read 80954 sequences (10000198 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 750, 1, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (274, 355, 481)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 895)
# [M::mem_pestat] mean and std.dev: (382.96, 151.24)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1102)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 80856 reads in 6.177 CPU sec, 5.952 real sec
# [M::process] read 80958 sequences (10000179 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 820, 1, 0)
# ...

# %%
# !freebayes -f usa300_reference.fna final_sorted.bam \
    --min-coverage 1 \
    --min-alternate-count 1 \
    --min-alternate-fraction 0.01 > final_variants.vcf
# !grep -v "^#" final_variants.vcf | wc -l
# Out:
# 58548

# %%
# !grep -v "^#" final_variants.vcf | head -5
# Out:
# NC_007795.1	127	.	T	C	1.66454e-05	.	AB=0;ABP=0;AC=0;AF=0;AN=2;AO=1;CIGAR=1X;DP=8;DPB=8;DPRA=0;EPP=5.18177;EPPR=3.32051;GTI=0;LEN=1;MEANALT=1;MQM=60;MQMR=60;NS=1;NUMALT=1;ODDS=12.4719;PAIRED=0;PAIREDR=0.428571;PAO=0;PQA=0;PQR=0;PRO=0;QA=14;QR=259;RO=7;RPL=0;RPP=5.18177;RPPR=5.80219;RPR=1;RUN=1;SAF=0;SAP=5.18177;SAR=1;SRF=3;SRP=3.32051;SRR=4;TYPE=snp	GT:DP:AD:RO:QR:AO:QA:GL	0/0:8:7,1:7:259:1:14:0,-1.00825,-22.2661
# NC_007795.1	290	.	A	G	238.679	.	AB=0;ABP=0;AC=2;AF=1;AN=2;AO=8;CIGAR=1X;DP=8;DPB=8;DPRA=0;EPP=12.7819;EPPR=0;GTI=0;LEN=1;MEANALT=1;MQM=60;MQMR=0;NS=1;NUMALT=1;ODDS=15.6955;PAIRED=0.5;PAIREDR=0;PAO=0;PQA=0;PQR=0;PRO=0;QA=296;QR=0;RO=0;RPL=3;RPP=4.09604;RPPR=0;RPR=5;RUN=1;SAF=2;SAP=7.35324;SAR=6;SRF=0;SRP=0;SRR=0;TYPE=snp	GT:DP:AD:RO:QR:AO:QA:GL	1/1:8:0,8:0:0:8:296:-26.9942,-2.40824,0
# ...

# %%
# !grep -v "^#" final_variants.vcf | wc -l
# !echo "Pipeline complete - variants called successfully"
# Out:
# 58548
# Pipeline complete - variants called successfully

# %%
# !git config --global user.email "vandanasaini0403@gmail.com"
# !git config --global user.name "vandanasaini04"

# %%
# !git init
# !git remote add origin https://github.com/vandanasaini04/variant-calling-pipeline.git
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# !git remote set-url origin https://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@github.com/vandanasaini04/variant-calling-pipeline.git

# %%
# !git add .
# !git commit -m "Add S aureus variant calling pipeline"
# !git push origin master
# Out:
# [master (root-commit) 6a36612] Add S aureus variant calling pipeline
#  67 files changed, 156383 insertions(+)
#  create mode 100644 .config/.last_opt_in_prompt.yaml
#  create mode 100644 .config/.last_survey_prompt.yaml
#  create mode 100644 .config/.last_update_check.json
#  create mode 100644 .config/active_config
#  create mode 100644 .config/config_sentinel
#  create mode 100644 .config/configurations/config_default
#  create mode 100644 .config/default_configs.db
#  create mode 100644 .config/gce
#  create mode 100644 .config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db
#  create mode 100644 .config/logs/2026.08.10/13.24.58.373513.log
#  create mode 100644 .config/logs/2026.08.10/13.25.25.328016.log
#  create mode 100644 .config/logs/2026.08.10/13.25.43.233148.log
#  create mode 100644 .config/logs/2026.08.10/13.26.03.888211.log
#  create mode 100644 .config/logs/2026.08.10/13.26.18.998373.log
#  create mode 100644 .config/logs/2026.08.10/13.26.19.834999.log
# ...

# %%
# !echo "*.fastq.gz" > .gitignore
# !echo "*.sam" >> .gitignore
# !echo "*.bam" >> .gitignore
# !echo "*.bai" >> .gitignore
# !echo "*.fna" >> .gitignore
# !echo "*.fna.*" >> .gitignore
# !echo "sample_data/" >> .gitignore
# !git rm -r --cached .
# !git add .gitignore
# !git add *.ipynb
# !git add *.vcf
# !git commit -m "Add variant calling pipeline notebook and results"
# !git push origin master
# Out:
# rm '.config/.last_opt_in_prompt.yaml'
# rm '.config/.last_survey_prompt.yaml'
# rm '.config/.last_update_check.json'
# rm '.config/active_config'
# rm '.config/config_sentinel'
# rm '.config/configurations/config_default'
# rm '.config/default_configs.db'
# rm '.config/gce'
# rm '.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db'
# rm '.config/logs/2026.08.10/13.24.58.373513.log'
# rm '.config/logs/2026.08.10/13.25.25.328016.log'
# rm '.config/logs/2026.08.10/13.25.43.233148.log'
# rm '.config/logs/2026.08.10/13.26.03.888211.log'
# rm '.config/logs/2026.08.10/13.26.18.998373.log'
# rm '.config/logs/2026.08.10/13.26.19.834999.log'
# rm 'R1_paired.fastq.gz'
# rm 'R1_unpaired.fastq.gz'
# rm 'R2_paired.fastq.gz'
# rm 'R2_unpaired.fastq.gz'
# rm 'SRR10346521_1.fastq.gz'
# rm 'SRR10346521_1_fastqc.html'
# rm 'SRR10346521_1_fastqc.zip'
# rm 'SRR10346521_2.fastq.gz'
# rm 'SRR10346521_2_fastqc.html'
# rm 'SRR10346521_2_fastqc.zip'
# rm 'aligned.sam'
# rm 'aligned2.sam'
# ...

# %%
# !echo "*.fastq.gz" > .gitignore
# !echo "*.sam" >> .gitignore
# !echo "*.bam" >> .gitignore
# !echo "*.bai" >> .gitignore
# !echo "*.fna" >> .gitignore
# !echo "*.fna.*" >> .gitignore
# !echo "*.vcf" >> .gitignore
# !echo "sample_data/" >> .gitignore
# !git rm -r --cached .
# !git add .gitignore
# !git add *.ipynb
# !git commit -m "Add variant calling pipeline notebook"
# !git push origin master --force
# Out:
# rm '.gitignore'
# rm 'final_variants.vcf'
# rm 'variants.vcf'
# rm 'variants2.vcf'
# rm 'variants3.vcf'
# fatal: pathspec '*.ipynb' did not match any files
# [master 0483e04] Add variant calling pipeline notebook
#  5 files changed, 1 insertion(+), 58792 deletions(-)
#  delete mode 100644 final_variants.vcf
#  delete mode 100644 variants.vcf
#  delete mode 100644 variants2.vcf
#  delete mode 100644 variants3.vcf
# Enumerating objects: 75, done.
# Counting objects: 100% (75/75), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (63/63), done.
# error: RPC failed; HTTP 408 curl 22 The requested URL returned error: 408
# send-pack: unexpected disconnect while reading sideband packet
# Writing objects: 100% (75/75), 3.25 GiB | 20.77 MiB/s, done.
# Total 75 (delta 8), reused 3 (delta 0), pack-reused 0
# fatal: the remote end hung up unexpectedly
# Everything up-to-date

# %%
# !ls *.ipynb
# Out:
# ls: cannot access '*.ipynb': No such file or directory

# %%
# !find / -name "*.ipynb" 2>/dev/null | grep -v ".ipynb_checkpoints"
# Out:
# /usr/local/lib/python3.12/dist-packages/nbclassic/bundler/tests/resources/empty.ipynb
# /usr/local/lib/python3.12/dist-packages/panel/tests/ui/io/app.ipynb
# /usr/local/lib/python3.12/dist-packages/notebook/bundler/tests/resources/empty.ipynb
# /usr/local/lib/python3.12/dist-packages/holoviews/examples/getting_started/4-Gridded_Datasets.ipynb
# /usr/local/lib/python3.12/dist-packages/holoviews/examples/getting_started/5-Live_Data.ipynb
# /usr/local/lib/python3.12/dist-packages/holoviews/examples/getting_started/3-Tabular_Datasets.ipynb
# /usr/local/lib/python3.12/dist-packages/holoviews/examples/getting_started/2-Customization.ipynb
# /usr/local/lib/python3.12/dist-packages/holoviews/examples/getting_started/1-Introduction.ipynb
# /usr/local/lib/python3.12/dist-packages/holoviews/examples/user_guide/07-Live_Data.ipynb
# /usr/local/lib/python3.12/dist-packages/holoviews/examples/user_guide/01-Annotating_Data.ipynb
# ...

# %%
# !git remote set-url origin https://github.com/vandanasaini04/variant-calling-pipeline.git
